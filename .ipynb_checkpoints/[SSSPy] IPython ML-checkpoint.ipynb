# %% [markdown]
# # Mailing List Analysis with BigBang

# %%
from __future__ import print_function
from bigbang.archive import Archive
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re as re
import networkx as nx
import bigbang as bb
# %matplotlib inline

# %% [raw]
# Wrapper f

# %%
class mArchive(object):
    def __init__(self, archives,names=False):
        self.rname = re.compile("(.+) \((.+)\)")
        self.disambigue_from(archives)
        self.data = [self.index(i.data) for i in archives]
        if names == False:
            names = range(0,len(self.data))
        self.ml_names = names
        #self.activity =  self.compute_activity(self.data,self.dict_mails)

    def index(self,df):
        df["Invididual"] = df["From"].apply(lambda x: self.dict_from[x])
        return df
        
    def unique_id(self,df):
        names = []
        mails = []
        for i in list(self.data["From"].values):
            mail,name = rname.match(i.lower().replace("\n"," ")).groups()
            names.append(name)
            mails.append(mail)
        return set(names),set(mails)
    
    def extract_from(self,d):
        try:
            mail,name = self.rname.match(d.lower().replace("\n"," ")).groups()
        except:
            print(d)
            mail,name = "na","na"
        return mail,name

    def network_mail_name(self,relations):
        G = nx.Graph()
        for i in relations:
            mail,name = i
            if not mail in G.node:
                G.add_node(mail, status = "mail")
            if not name in G.node:
                G.add_node(name, status = "name")
            G.add_edge(mail,name)
        return G

    def dict_name_mail_cluster(self,G):
        dict_clusters = {}
        dict_individual = {}
        dict_mails = {}
        l = sorted(nx.connected_components(G), key = len, reverse=True)
        for i in range(0,len(l)):
            if len(l[i])>10:
                print("\nCareful, a component contain more than 10 entities. Maybe there is an homonym")
                print(l[i])
                print("n\n")
            for j in l[i]:
                dict_clusters[j] = i
            a = dict_individual[i] = sorted([u for u in l[i] if not "@" in u and not " at " in u], key = len, reverse=True)
            if len(a)==0:
                dict_individual[i] = l[i][0]
            else:
                dict_individual[i] = a[0]
        for i in [i for i in G.node if G.node[i]["status"]=='mail']:
            name = dict_individual[dict_clusters[i]].replace("=f6","o").replace("e9","e").replace("?iso-8859-1?q?","").replace("?=","").replace("=?windows-1252?q?","").replace("=","").replace("?windows-1250?q?","").replace("?iso-8859-15?q?","").replace("_"," ")
            dict_mails[i] = name.title()+" [id:"+str(dict_clusters[i])+"]"
        return dict_clusters,dict_individual, dict_mails

    def dict_from(self,from_set):
        from_cleaned =  {}
        for i in from_set:
            from_cleaned[i] = self.attribute_id(i,self.dict_mails)
        return from_cleaned

    def attribute_id(self,from_field,dict_id):
        mail,name = self.extract_from(from_field)
        try:
            return dict_id[mail]
        except:
            return "na"

    def compute_activity(self,mdf,dict_id):
        mdf["Id"] = mdf['From'].apply(lambda x: self.attribute_id(x,dict_id))
        mdf2 = mdf.reindex(columns = ['Id', 'Date'])
        mdf2['Date'] = mdf['Date'].apply(lambda x: x.toordinal())
        activity = mdf2.groupby(
            ['Id', 'Date']).size().unstack('Id').fillna(0)
        new_date_range = np.arange(mdf2['Date'].min(), mdf2['Date'].max())
        activity = activity.reindex(new_date_range, fill_value=0)
        return activity
    
    def display_list_individuals(self,n):
        ta = self.activity.sum(0) # sum along the first axis
        ta.sort()
        ta[-n:].plot(kind='barh', width=1)
        plt.show()
        print(ta[-n:])
        
    def weighted_individuals(self):
        ta = self.activity.sum(0) # sum along the first axis
        ta.sort()
        return ta
    
    def disambigue_from(self,mls):
        from_set = []
        for i in mls:
            from_set+=list(i.data["From"])
        id_set = [self.extract_from(i) for i in from_set]
        G = self.network_mail_name(id_set)
        self.dict_clusters,self.dict_individual,self.dict_mails = self.dict_name_mail_cluster(G)
        self.dict_from = self.dict_from(from_set)
        
    def network_between_mls(self,n):
        G = nx.Graph()
        #m = np.zeros((len(self.data),len(self.data)))
        #first_n = [(i["Invididual"]).value_counts()[0:n].keys() for i in self.data]
        #for i in range(0,len(self.data)):
        #    for j in range(i+1,len(self.data)):
        #        m[i,j] = len(set(first_n[i]).intersection(first_n[j]))
        #        m[j,i] = m[i,j]
        #return m
        for i in range(0, len(self.data)):
            t = int(sum(self.data[i]["Invididual"].value_counts()))
            G.add_node(str(self.ml_names[i]),Label=str(self.ml_names[i]),status="ML",weight=t)
            d = self.data[i]["Invididual"].value_counts()[0:n]
            for j in d.keys():
                if not j in G.node:
                    G.add_node(j,Label=j,Status="Individual",weight=int(d[j]))
                else:
                    G.node[j]["weight"]+=int(d[j])
                G.add_edge(j,self.ml_names[i],weight = int(d[j]/(0.1*t)))
        nx.write_graphml(G,"network_mls.graphml")
        return G

# %%
names = ["astropy","ipython-dev","ipython-user","scipy-dev","scipy-user","numpy-discussion","pandas-dev","cython-devel","nipy-devel"]
mls = []
for i in names:
    mls.append(Archive(i, archive_dir='../bigbang/archives'))

# %%
a = Archive("ipython-dev", archive_dir='../archives')
b = Archive("ipython-user", archive_dir='../archives')

# %%
store = pd.HDFStore('store.h5')
store["ipythondev"] = a.data
store["ipythonuser"] = b.data

# %%
t = mArchive(mls,names)
# Out:
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['dave.hirschfeld', 'pearu peterson', 'peterson at math.utwente.nl', 'davbrow at gmail.com', 'david hirschfeld', 'novin01@gmail....', 'pearu@cens.ioc...', 'pearu', 'dave', 'dave hirschfeld', 'pearu at scipy.org', 'pearu.peterson@gmail....', 'pearu at ioc.ee', 'davestechshop@gmail....', 'pearu.peterson at gmail.com', 'p.peterson', 'pearu at cens.ioc.ee', 'dave.hirschfeld@gmail....', 'dave.hirschfeld at gmail.com']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['argriffi', 'z99719@gmail....', 'alex', 'alex griffing', 'alex.liberzon@gmail....', 'alexlib@eng.tau.ac...', 'alex.at.workplace@googlemail....', 'z99719 z99719', 'alex.liberzon at gmail.com', 'argriffi@ncsu....', 'zdoor@xs4all...', 'alex van der spek', 'alex liberzon']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['oliphant.travis at ieee.org', 'oliphant at ee.byu.edu', 'travis@continuum...', 'enthought', 'travis e. oliphant', 'oliphant.travis at mayo.edu', 'teoliphant@gmail....', 'oliphant at enthought.com', 'travis oliphant', 'oliphant@ee.byu....', 'oliphant.travis@ieee....', 'oliphant@enthought....', 'travisoliphant at netscape.net']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['fernando.perez@colorado.edu', 'fperez@colorado.edu', 'fperez.net at gmail.com', 'ipython at gmail.com', 'fernando.perez-1 at colorado.edu', 'fernando.perez@colorado....', 'fernando perez', '=?iso-8859-1?q?fernando_p=e9rez?=', 'fernando.perez@berkeley....', 'fperez at pizero.colorado.edu', 'fperez at colorado.edu', 'fperez.net@gmail....', 'fernando.perez at colorado.edu']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['bhoel at web.de', 'berthold hoellmann', '=?iso-8859-15?q?berthold_h=f6llmann?=', 'berthold =?iso-8859-15?q?h=f6llmann?=', '=?iso-8859-15?q?_berthold_h=f6llmann?=', '=?iso-8859-1?q?berthold_h=f6llmann?=', 'berthold =?iso-8859-1?q?h=f6llmann?=', '=?iso-8859-15?q?berthold_=22h=f6llmann=22?=', 'berthold.hoellmann@gl-group....', 'hoel at gl-group.com', 'berthold@despammed....', 'hoel at germanlloyd.org', 'berthold.hoellmann at gl-group.com']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['stefan.czesla@hs.uni-hamburg...', '=?iso-8859-1?q?st=e9fan_van_der_walt?=', 'stefan van der walt', '=?iso-8859-1?q?st=e9fan?= van der walt', 'stefan', '=?utf-8?q?st=c3=a9fan_van_der_walt?=', 'stefan@sun.ac...', '=?utf-8?q?st=c3=a9fan?= van der walt', 'stefan.peterson@rubico....', 'stefan at sun.ac.za', 'shmueller2@gmail....', 'stefan czesla']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['c. ball', 'fonnesbeck@gmail....', 'chris fonnesbeck', 'ceball@users.sourceforge....', 's0454615@sms.ed.ac...', 'fonnesbeck at gmail.com', 'listservs@mac....', 'chris.madan@gmail....', 'chris ball', 'chris', 'ceball@gmail....', 'christopher ball']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['faltet at pytables.org', 'faltet at gmail.com', 'faltet at carabos.com', 'falted at openlc.org', 'francesc alted', 'faltet@pytables....', 'falted at pytables.org', 'faltet@carabos....', 'francesc@continuum...', 'faltet@gmail....', 'francesc altet', 'falted@pytables....']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['mike at pcblokes.com', 'supermihi at posteo.de', 'fuzzyman@voidspace.org.uk', 'michael', 'fuzzyman@voidspace.org...', 'mike@pcblokes.com', 'michael foord', 'voidspace', 'fuzzyman', 'mnandris@blueyonder.co...', 'fuzzyman at voidspace.org.uk']
# n
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['david cournapeau', 'cournapeau@cslab.kecl.ntt.co...', 'david at ar.media.kyoto-u.ac.jp', 'cournape@gmail....', 'david', 'ldl08@gmx....', 'dcuccia@gmail....', 'david@ar.media.kyoto-u.ac...', 'cournape at gmail.com', 'davidlinke at tiscali.de', 'david@silveregg.co...']
# n
#
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()
# bogus@does.not.exist.com ()

# %%
t.network_between_mls(100)

# %%
t.data[0]["Invididual"].value_counts()[0:10]["Thomas Kluyver [id:1168]"]
# Out:
# 1095

# %%
ml_dev = Archive("ipython-dev",archive_dir="../archives")
ml_user = Archive("ipython-user",archive_dir="../archives")
ml_list = {"Ipython development ML":ml_dev,"Ipython user ML":ml_user}

# %% [markdown]
# **Name/Mail cleaning with networkx component function and dictionnaries to link names/mails/id**

# %% [markdown]
# # Participation sur la ML

# %%
for ml_name in ml_list:
    print("\n\n###{name}###\n".format(name=ml_name))
    ml = ml_list[ml_name]
    dict_clusters,dict_individual,dict_mails = dict_name_mail_cluster(network_mail_name(ml.data))
    print("There are {nbr} unique id after cleaning\n\n".format(nbr=len(dict_individual)))
    a = compute_activity(ml.data,dict_mails)
    ta = a.sum(0) # sum along the first axis
    ta.sort()
    ta[-20:].plot(kind='barh', width=1)
    plt.show()
    print(ta[-20:])
# Out:
# Ipython user ML
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['fernando.perez@colorado.edu', 'fperez@colorado.edu', 'fperez.net at gmail.com', 'ipython at gmail.com', 'fernando.perez-1 at colorado.edu', 'fernando.perez@colorado....', 'fernando perez', 'fernando.perez@berkeley....', 'fperez at colorado.edu', 'fperez.net@gmail....', 'fernando.perez at colorado.edu']
# n
#
# There are 1085 unique id after cleaning
# Id
# Paul Ivanov [id:219]                   67
# Carl Joseph Younger [id:122]           75
# Frederic Mantegazza [id:129]           77
# Prabhu Ramachandran [id:1]             81
# Alexander Schmolck [id:91]             82
# Darren Govoni [id:80]                  85
# Zolte1N Voros [id:24]                  94
# John Hunter [id:222]                  102
# Jorgen Stenarson [id:2]               103
# ?Utf-8?Q?Gc3B6Khan Sever [id:878]     114
# Ryan Krauss [id:42]                   131
# Aaron S. Meurer [id:73]               132
# Robert Kern [id:45]                   152
# Klonuo Umom [id:7]                    221
# Matthias Bussonnier [id:817]          365
# Brian Granger [id:10]                 542
# Ville M. Vainio [id:11]               650
# Thomas Kluyver [id:896]               653
# Min Rk [id:196]                       653
# Fernando Perez [id:0]                2549
# dtype: float64
#
#
# Ipython development ML
#
# There are 720 unique id after cleaning
# Id
# Laurent Dufrechou [id:1]         112
# Darren Dale [id:9]               116
# Ondrej Certik [id:622]           116
# Damie1N Avila [id:7]             131
# Zolte1N Voros [id:15]            154
# Satrajit Ghosh [id:138]          156
# Aaron S. Meurer [id:33]          157
# Hans Meine [id:46]               175
# Doug Blank [id:368]              186
# Carl Joseph Younger [id:112]     192
# Jorgen Stenarson [id:2]          235
# Jason Grout [id:36]              260
# Robert Kern [id:13]              274
# Gaebl Varoquaux [id:21]          288
# Matthias Bussonnier [id:101]     643
# Ville M. Vainio [id:8]           762
# Min Rk [id:98]                   869
# Thomas Kluyver [id:544]         1095
# Brian Granger [id:3]            1402
# Fernando Perez [id:0]           3254
# dtype: float64

# %% [markdown]
# ** When do they send their first mail ? **

# %%
for ml_name in ml_list:
    ml = ml_list[ml_name]
    print("\n\n###{name}###\n".format(name=ml_name))
    fig = plt.figure(figsize=(8, 4))
    dict_clusters,dict_individual,dict_mails = dict_name_mail_cluster(network_mail_name(ml.data))
    a = compute_activity(ml.data,dict_mails)
    (a > 0).idxmax().hist(bins=20)
    plt.title("Incomers by period")
    fig.axes[0].xaxis_date()
    plt.show()
# Out:
# ###Ipython user ML###
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['fernando.perez@colorado.edu', 'fperez@colorado.edu', 'fperez.net at gmail.com', 'ipython at gmail.com', 'fernando.perez-1 at colorado.edu', 'fernando.perez@colorado....', 'fernando perez', 'fernando.perez@berkeley....', 'fperez at colorado.edu', 'fperez.net@gmail....', 'fernando.perez at colorado.edu']
# n
# ###Ipython development ML###

# %%
from bigbang import plot
n = 5

for ml_name in ml_list:
    ml = ml_list[ml_name]
    print("\n\n###{name}###\n".format(name=ml_name))
    dict_clusters,dict_individual,dict_mails = dict_name_mail_cluster(network_mail_name(ml.data))
    a = compute_activity(ml.data,dict_mails)    
    first_post = (a > 0).idxmax().order()
    cohorts = np.array_split(first_post,n)
    cohorts = [c.keys() for c in cohorts]
    print("Evolution from {a} cohorts".format(a=str(n)))
    plot.stack(a,partition=cohorts,smooth=100)
# Out:
# ###Ipython user ML###
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['fernando.perez@colorado.edu', 'fperez@colorado.edu', 'fperez.net at gmail.com', 'ipython at gmail.com', 'fernando.perez-1 at colorado.edu', 'fernando.perez@colorado....', 'fernando perez', 'fernando.perez@berkeley....', 'fperez at colorado.edu', 'fperez.net@gmail....', 'fernando.perez at colorado.edu']
# n
#
# Evolution from 5 cohorts
# ###Ipython development ML###
#
# Evolution from 5 cohorts

# %% [markdown]
# ## Threads

# %%
for ml_name in ml_list:
    ml = ml_list[ml_name]
    print("\n\n###{name}###\n".format(name=ml_name))
    ml.get_threads()
    y = [t.get_num_messages() for t in ml.get_threads()]
    plt.hist(y, bins=30)
    plt.xlabel('number of messages in a thread')
    plt.show()
# Out:
# ###Ipython user ML###
# ###Ipython development ML###

# %% [markdown]
# **Who starts threads ?**

# %%
for ml_name in ml_list:
    ml = ml_list[ml_name]
    print("\n\n###{name}###\n".format(name=ml_name))
    dict_clusters,dict_individual,dict_mails = dict_name_mail_cluster(network_mail_name(ml.data))
    senders = pd.Series([attribute_id(i.get_root().data["From"],dict_mails) for i in ml.get_threads() if i.known_root])
    senders.value_counts()[0:20].plot(kind='barh')
    plt.show()
# Out:
# ###Ipython user ML###
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['fernando.perez@colorado.edu', 'fperez@colorado.edu', 'fperez.net at gmail.com', 'ipython at gmail.com', 'fernando.perez-1 at colorado.edu', 'fernando.perez@colorado....', 'fernando perez', 'fernando.perez@berkeley....', 'fperez at colorado.edu', 'fperez.net@gmail....', 'fernando.perez at colorado.edu']
# n
# ###Ipython development ML###

# %% [markdown]
# **Who answers threads ?**

# %%
for ml_name in ml_list:
    ml = ml_list[ml_name]
    print("\n\n###{name}###\n".format(name=ml_name))
    dict_clusters,dict_individual,dict_mails = dict_name_mail_cluster(network_mail_name(ml.data))
    respondents = pd.Series([attribute_id(i.get_root().get_successors()[0].data["From"],dict_mails) for i in ml.get_threads() if i.known_root and i.get_num_messages()>1])
    respondents.value_counts()[0:20].plot(kind='barh')
    plt.show()
# Out:
# ###Ipython user ML###
#
#
# Careful, a component contain more than 10 entities. Maybe there is an homonym
# ['fernando.perez@colorado.edu', 'fperez@colorado.edu', 'fperez.net at gmail.com', 'ipython at gmail.com', 'fernando.perez-1 at colorado.edu', 'fernando.perez@colorado....', 'fernando perez', 'fernando.perez@berkeley....', 'fperez at colorado.edu', 'fperez.net@gmail....', 'fernando.perez at colorado.edu']
# n
# ###Ipython development ML###

# %%
with open("content-mail-python.txt","w") as f:
    for ml_name in ml_list:
        ml = ml_list[ml_name]
        ml_name=ml_name.replace(" ","")
        for i in ml.data["Body"]:
            try:
                f.write("\n**** *list_{list}\n{content}\n".format(list=ml_name,content=i.replace("*"," ")))
            except:
                print(i)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None

# %%
import datetime
datetime.datetime(2006, 6, 14).toordinal()
# Out:
# 732476

# %%
from bs4 import BeautifulSoup
import urllib2 as ul

# %%
response = ul.urlopen("http://sourceforge.net/p/scikit-learn/mailman/scikit-learn-general/?page=713")
html = response.read()

# %%
soup = BeautifulSoup(html,"html.parser")
table = soup.findAll("table")

# %%
soup
# Out:
# <!DOCTYPE html>\n\n<!-- Server: sfn-web-1 -->\n<!--[if lt IE 7 ]> <html lang="en" class="no-js ie6"> <![endif]-->\n<!--[if IE 7 ]>    <html lang="en" class="no-js ie7"> <![endif]-->\n<!--[if IE 8 ]>    <html lang="en" class="no-js ie8"> <![endif]-->\n<!--[if IE 9 ]>    <html lang="en" class="no-js ie9"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]>-->\n<html class="no-js" lang="en"> <!--<![endif]-->\n<head>\n<meta content="text/html; charset=unicode-escape" http-equiv="content-type"/>\n<title>Scikit Learn / Mailing Lists</title>\n<meta content="scikit-learn" id="project_name" name="project_name"/>\n<script src="http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/js/sftheme/modernizr.custom.90514.js"></script>\n<!--[if lt IE 7 ]>\n  <script src="http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/js/sftheme/dd_belatedpng.js"></script>\n  <script> DD_belatedPNG.fix('img, .png_bg'); //fix any <img> or .png_bg background-images </script>\n<![endif]-->\n<link href="//fonts.googleapis.com/css?family=Ubuntu:regular" rel="stylesheet" type="text/css">\n<style type="text/css">\n    @font-face {\n        font-family: "Pictos";\n        src: url('http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/css/fonts/sftheme/pictos-web.eot');\n        src: local("\u263a"), url('http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/css/fonts/sftheme/pictos-web.woff') format('woff'), url('http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/css/fonts/sftheme/pictos-web.ttf') format('truetype'), url('http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/css/fonts/sftheme/pictos-web.svg') format('svg');\n    }\n</style>\n<script type="text/javascript">\n        /*jslint onevar: false, nomen: false, evil: true, css: true, plusplus: false, white: false, forin: true, on: true, immed: false */\n        /*global confirm, alert, unescape, window, jQuery, $, net, COMSCORE */\n    </script>\n<!-- ew:head_css -->\n<link href="http://a.fsdn.com/allura/nf/1436989050/_ew_/_slim/css?href=tool%2Fmailman%2Fcss%2Fmailman.css%3Ballura%2Fcss%2Fforge%2Fhilite.css%3Ballura%2Fcss%2Fforge%2Ftooltipster.css" rel="stylesheet" type="text/css">\n<link href="/nf/tool_icon_css?1436989050" rel="stylesheet" type="text/css">\n<link href="http://a.fsdn.com/allura/nf/1436989050/_ew_/theme/sftheme/css/forge.css" rel="stylesheet" type="text/css">\n<link href="http://a.fsdn.com/allura/nf/1436989050/_ew_/_slim/css?href=css%2Fpage_list.css" rel="stylesheet" type="text/css">\n<!-- /ew:head_css -->\n<!-- ew:head_js -->\n<script src="http://a.fsdn.com/allura/nf/1436989050/_ew_/_slim/js?href=allura%2Fjs%2Fjquery-base.js" type="text/javascript"></script>\n<!-- /ew:head_js -->\n<style type="text/css">\n            #page-body.project---init-- #top_nav { display: none; }\r\n\r\n#page-body.project---init-- #nav_menu_holder { display: none; margin-bottom: 0; }\r\n\r\n#page-body.project---init-- #content_base {margin-top: 0; }\n        </style>\n<style>.XWgRJkREOyjeGPoMpidQFnc {\n        display: none\n    }</style>\n<script type="text/javascript">\n    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n            (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n        m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');\n\n    function _add_tracking(prefix, tracking_id) {\n        ga('create', tracking_id, {cookieDomain: 'auto', 'name': prefix});\n        \n        ga(prefix+'.set', 'dimension9', 'scikit-learn');\n        ga(prefix+'.set', 'dimension10', 'mailman');\n        ga(prefix+'.send', 'pageview');\n    }\n      _add_tracking('sfnt1', 'UA-32013-6');\n      _add_tracking('sfnt2', 'UA-36130941-1');\n    \n</script>\n</link></link></link></link></link></head>\n<body id="forge">\n<h2 class="hidden">\n<span style="color:red">Error:</span> CSS did not load.<br>\n    This may happen on the first request due  ...

# %%
from bigbang import repo_loader # The file that handles most loading

repo = repo_loader.get_repo("https://github.com/sbenthall/bigbang.git", in_type = "remote" )
# Out:
# Gloning the repo from remote
# Checking for ipython at /home/schultz/Scripts/bigbang/archives/sample-git-repos/ipython
# ERROR:git.objects.commit:Failed to decode author line 'author J�rgen Stenarson <jorgen.stenarson@kroywen.se> 1346087511 +0200
# ' using encoding UTF-8
# Traceback (most recent call last):
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/site-packages/git/objects/commit.py", line 483, in _deserialize
#     parse_actor_and_date(author_line.decode(self.encoding))
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/encodings/utf_8.py", line 16, in decode
#     return codecs.utf_8_decode(input, errors, True)
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xf6 in position 8: invalid start byte
# ERROR:git.objects.commit:Failed to decode committer line 'committer J�rgen Stenarson <jorgen.stenarson@kroywen.se> 1346087511 +0200
# ' using encoding UTF-8
# Traceback (most recent call last):
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/site-packages/git/objects/commit.py", line 490, in _deserialize
#     parse_actor_and_date(committer_line.decode(self.encoding))
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/encodings/utf_8.py", line 16, in decode
#     return codecs.utf_8_decode(input, errors, True)
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xf6 in position 11: invalid start byte
# ERROR:git.objects.commit:Failed to decode author line 'author J�rgen Stenarson <jorgen.stenarson@kroywen.se> 1346087511 +0200
# ' using encoding UTF-8
# Traceback (most recent call last):
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/site-packages/git/objects/commit.py", line 483, in _deserialize
#     parse_actor_and_date(author_line.decode(self.encoding))
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/encodings/utf_8.py", line 16, in decode
#     return codecs.utf_8_decode(input, errors, True)
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xf6 in position 8: invalid start byte
# ERROR:git.objects.commit:Failed to decode committer line 'committer J�rgen Stenarson <jorgen.stenarson@kroywen.se> 1346087511 +0200
# ' using encoding UTF-8
# Traceback (most recent call last):
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/site-packages/git/objects/commit.py", line 490, in _deserialize
#     parse_actor_and_date(committer_line.decode(self.encoding))
#   File "/home/schultz/.conda/envs/p2/lib/python2.7/encodings/utf_8.py", line 16, in decode
#     return codecs.utf_8_decode(input, errors, True)
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xf6 in position 11: invalid start byte
# WARNING: Currently going through file diffs. This will take a very long time (1 minute per 3000 commits.) We suggest using a small repository.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-57406706ca0b> in <module>()
#       1 from bigbang import repo_loader # The file that handles most loading
#       2
# ----> 3 repo = repo_loader.get_repo("https://github.com/ipython/ipython.git", in_type = "remote" )
#
# /home/schultz/Scripts/bigbang/bigbang/repo_loader.pyc in get_repo(repo_in, in_type, update)
#     155             print("Gloning the repo from remote")
#     156             fetch_repo(repo_in);
# --> 157         return get_repo(name, 'name', update);
#     158
#     159     else:
#
# /home/schultz/Scripts/bigbang/bigbang/repo_loader.pyc in get_repo(repo_in, in_type, update)
#     132             return ans;
#     133         print("Checking for " + str(repo_in) + " at " + str(filepath));
# --> 134         ans = get_repo(filepath, 'local', update);
#     135
#     136         if isinstance(ans, GitRepo):
#
# /home/schultz/Scripts/bigbang/bigbang/repo_loader.pyc in get_repo(repo_in, in_type, update)
#     144         if repo_already_exists(repo_in):
#     145             name = filepath_to_name(repo_in);
# --> 146             return GitRepo(url=repo_in, name=name);
#     147         else:
#     148             print("Invalid filepath: " + repo_in);
#
# /home/schultz/Scripts/bigbang/bigbang/git_repo.py in __init__(self, name, url, attribs, cache)
#      35         if cache is None:
#      36             self.repo = Repo(url)
# ---> 37             self.populate_data(ALL_ATTRIBUTES)
#      38         else:
#      39             cache = cache.apply(cache_fixer, axis=1)
#
# /home/schultz/Scripts/bigbang/bigbang/git_repo.py in populate_data(self, attribs)
#     104             raw[attrib] = list();
#     105         repo = self.repo
# --> 106         self.gen_data(repo, raw);
#     107         print(type(raw["Time"]))
#     108
#
# /home/schultz/Scripts/bigbang/bigbang/git_repo.py in gen_data(self, repo, raw)
#      79
#      80                 if "Committer Name" in raw:
# ---> 81                     raw["Committer Name"].append(commit.committer.name)
#      82
#      83                 if "Committer Email" in raw:
#
# /home/schultz/.conda/envs/p2/lib/python2.7/site-packages/gitdb/util.pyc in __getattr__(self, attr)
#     237         self._set_cache_(attr)
#     238         # will raise in case the cache was not created
# --> 239         return object.__getattribute__(self, attr)
#     240
#     241     def _set_cache_(self, attr):
#
# AttributeError: committer

# %%
dir(git)
# Out:
# 'bigbang'

# %%
git.Repo??
